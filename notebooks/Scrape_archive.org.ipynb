# %% [markdown]
# # archive.org scraper
#
# Import dependencies:

# %%
from selenium import webdriver
import time
import os

# %% [markdown]
# Get a list of the tars that I have already downloaded:

# %%
downloaded_tars = os.listdir('../data/archive')
downloaded_tars = [x.split('.')[0] for x in downloaded_tars]
print('Number of downloaded tars: ' + str(len(downloaded_tars)))
# Out:
# Number of downloaded tars: 2929

# %% [markdown]
# Define scraping functions:

# %%
def initialize():
    # Construct browser and profile (to prevent download dialog)
    # https://stackoverflow.com/questions/25251583/downloading-file-to-specified-location-with-selenium-and-python
    profile = webdriver.FirefoxProfile()
    profile.set_preference('browser.download.folderList', 2)
    profile.set_preference('browser.download.manager.showWhenStarting', False)
    profile.set_preference('browser.download.dir', '/Volumes/BRIENNAKH/Thesis/data/archive')
    profile.set_preference('browser.helperApps.neverAsk.saveToDisk', 'application/x-tar')
    return webdriver.Firefox(profile, executable_path='/usr/local/bin/geckodriver') # brew install chromedriver then see in terminal where it was installed to and paste this

def scroll(browser):
    # https://stackoverflow.com/questions/20986631/how-can-i-scroll-a-web-page-using-selenium-webdriver-in-python
    SCROLL_PAUSE_TIME = 2
    # Get scroll height
    last_height = browser.execute_script('return document.body.scrollHeight')
        
    while True:
        # Scroll down to bottom
        browser.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        # Wait to load page
        time.sleep(SCROLL_PAUSE_TIME)
        # Calculate new scroll height and compare with last scroll height
        new_height = browser.execute_script('return document.body.scrollHeight')
        if new_height == last_height:
            break
        last_height = new_height

# %% [markdown]
# Run scraper. Keep browser open and run the next cell.

# %%
# Initialize browser
browser = initialize()

# Navigate to page with search results
browser.get('https://archive.org/search.php?query=arXiv_src&sort=-publicdate')

# Scroll until the results end
scroll(browser)

# Collect all attributes
names = []
results = browser.find_elements_by_xpath('//div[@data-id]')
for result in results:
    name = result.get_attribute('data-id')
    if 'arXiv' in name:
        names.append(name)
        
# Print difference in downloaded & archived files
print('Files in my downloaded tars that aren\'t in the archive: ' 
      + str(len(list(set(downloaded_tars) - set(names)))))

print('Files in the archive that aren\'t in my downloaded tars: ' 
     + str(len(list(set(names) - set(downloaded_tars)))))
# Out:
# Files in my downloaded tars that aren't in the archive: 0
# Files in the archive that aren't in my downloaded tars: 336

# %% [markdown]
# The Internet Archive has all of the tar files that I downloaded from Amazon S3. And they're free!

# %% [markdown]
# Go to the download page for each file I haven't already downloaded, and it will download:

# %%
for name in names:
    if name not in downloaded_tars:
        print('Downloading ' + name + '...')
        browser.get('https://archive.org/download/' + name)
        browser.find_element_by_partial_link_text('.tar').click()
        time.sleep(120) # wait 2 min to let download progress (it won't end but this prevents overflow)
    
    # could find a way to wait until the file appears in download directory, but I just put time.sleep
# Out:
# Downloading arXiv_src_2006_060...
# Downloading arXiv_src_2006_061...
# Downloading arXiv_src_2006_059...
# Downloading arXiv_src_2006_057...
# Downloading arXiv_src_2006_058...
# Downloading arXiv_src_2006_055...
# Downloading arXiv_src_2006_054...
# Downloading arXiv_src_2006_056...
# Downloading arXiv_src_2006_053...
# Downloading arXiv_src_2006_052...
# Downloading arXiv_src_2006_051...
# Downloading arXiv_src_2006_050...
# Downloading arXiv_src_2006_049...
# Downloading arXiv_src_2006_048...
# Downloading arXiv_src_2006_047...
# Downloading arXiv_src_2006_046...
# Downloading arXiv_src_2006_045...
# Downloading arXiv_src_2006_044...
# Downloading arXiv_src_2006_043...
# Downloading arXiv_src_2006_042...
# Downloading arXiv_src_2006_041...
# Downloading arXiv_src_2006_040...
# Downloading arXiv_src_2006_038...
# Downloading arXiv_src_2006_039...
# Downloading arXiv_src_2006_037...
# Downloading arXiv_src_2006_034...
# Downloading arXiv_src_2006_035...
# Downloading arXiv_src_2006_036...
# Downloading arXiv_src_2006_033...
# Downloading arXiv_src_2006_032...
# Downloading arXiv_src_2006_031...
# Downloading arXiv_src_2006_028...
# Downloading arXiv_src_2006_030...
# Downloading arXiv_src_2006_029...
# Downloading arXiv_src_2006_027...
# Downloading arXiv_src_2006_026...
# Downloading arXiv_src_2006_024...
# Downloading arXiv_src_2006_025...
# Downloading arXiv_src_2006_022...
# Downloading arXiv_src_2006_021...
# Downloading arXiv_src_2006_023...
# Downloading arXiv_src_2006_019...
# Downloading arXiv_src_2006_020...
# Downloading arXiv_src_2006_018...
# Downloading arXiv_src_2006_016...
# Downloading arXiv_src_2006_017...
# Downloading arXiv_src_2006_015...
# Downloading arXiv_src_2006_014...
# Downloading arXiv_src_2006_013...
# Downloading arXiv_src_2006_012...
# Downloading arXiv_src_2006_010...
# Downloading arXiv_src_2006_011...
# Downloading arXiv_src_2006_009...
# Downloading arXiv_src_2006_007...
# Downloading arXiv_src_2006_008...
# Downloading arXiv_src_2006_006...
# Downloading arXiv_src_2006_004...
# Downloading arXiv_src_2006_005...
# Downloading arXiv_src_2006_003...
# Downloading arXiv_src_2006_002...
# Downloading arXiv_src_2006_001...
# Downloading arXiv_src_2005_050...
# Downloading arXiv_src_2005_049...
# Downloading arXiv_src_2005_048...
# Downloading arXiv_src_2005_047...
# Downloading arXiv_src_2005_046...
# Downloading arXiv_src_2005_044...
# Downloading arXiv_src_2005_045...
# Downloading arXiv_src_2005_043...
# Downloading arXiv_src_2005_042...
# Downloading arXiv_src_2005_041...
# Downloading arXiv_src_2005_039...
# Downloading arXiv_src_2005_040...
# Downloading arXiv_src_2005_038...
# Downloading arXiv_src_2005_037...
# Downloading arXiv_src_2005_036...
# Downloading arXiv_src_2005_035...
# Downloading arXiv_src_2005_034...
# Downloading arXiv_src_2005_033...
# Downloading arXiv_src_2005_032...
# Downloading arXiv_src_2005_030...
# Downloading arXiv_src_2005_031...
# Downloading arXiv_src_2005_029...
# Downloading arXiv_src_2005_026...
# Downloading arXiv_src_2005_028...
# Downloading arXiv_src_2005_027...
# Downloading arXiv_src_2005_025...
# Downloading arXiv_src_2005_024...
# Downloading arXiv_src_2005_023...
# Downloading arXiv_src_2005_021...
# Downloading arXiv_src_2005_022...
# Downloading arXiv_src_2005_020...
# Downloading arXiv_src_2005_018...
# Downloading arXiv_src_2005_019...
# Downloading arXiv_src_2005_017...
# Downloading arXiv_src_2005_016...
# Downloading arXiv_src_2005_015...
# Downloading arXiv_src_2005_014...
# Downloading arXiv_src_2005_013...
# Downloading arXiv_src_2005_012...
# Downloading arXiv_src_2005_010...
# Downloading arXiv_src_2005_011...
# Downloading arXiv_src_2005_009...
# Downloading arXiv_src_2005_008...
# Downloading arXiv_src_2005_007...
# Downloading arXiv_src_2005_006...
# Downloading arXiv_src_2005_004...
# Downloading arXiv_src_2005_005...
# Downloading arXiv_src_2005_001...
# Downloading arXiv_src_2005_002...
# Downloading arXiv_src_2005_003...
# Downloading arXiv_src_2004_050...
# Downloading arXiv_src_2004_051...
# Downloading arXiv_src_2004_049...
# Downloading arXiv_src_2004_048...
# Downloading arXiv_src_2004_047...
# Downloading arXiv_src_2004_045...
# Downloading arXiv_src_2004_046...
# Downloading arXiv_src_2004_044...
# Downloading arXiv_src_2004_043...
# Downloading arXiv_src_2004_042...
# Downloading arXiv_src_2004_041...
# Downloading arXiv_src_2004_040...
# Downloading arXiv_src_2004_037...
# Downloading arXiv_src_2004_038...
# Downloading arXiv_src_2004_039...
# Downloading arXiv_src_2004_033...
# Downloading arXiv_src_2004_036...
# Downloading arXiv_src_2004_035...
# Downloading arXiv_src_2004_034...
# Downloading arXiv_src_2004_032...
# Downloading arXiv_src_2004_030...
# Downloading arXiv_src_2004_029...
# Downloading arXiv_src_2004_031...
# Downloading arXiv_src_2004_027...
# Downloading arXiv_src_2004_026...
# Downloading arXiv_src_2004_028...
# Downloading arXiv_src_2004_023...
# Downloading arXiv_src_2004_025...
# Downloading arXiv_src_2004_024...
# Downloading arXiv_src_2004_021...
# Downloading arXiv_src_2004_020...
# Downloading arXiv_src_2004_018...
# Downloading arXiv_src_2004_022...
# Downloading arXiv_src_2004_019...
# Downloading arXiv_src_2004_017...
# Downloading arXiv_src_2004_015...
# Downloading arXiv_src_2004_016...
# Downloading arXiv_src_2004_014...
# Downloading arXiv_src_2004_013...
# Downloading arXiv_src_2004_012...
# Downloading arXiv_src_2004_011...
# Downloading arXiv_src_2004_010...
# Downloading arXiv_src_2004_009...
# Downloading arXiv_src_2004_008...
# Downloading arXiv_src_2004_007...
# Downloading arXiv_src_2004_006...
# Downloading arXiv_src_2004_004...
# Downloading arXiv_src_2004_005...
# Downloading arXiv_src_2004_002...
# Downloading arXiv_src_2004_003...
# Downloading arXiv_src_2004_001...
# Downloading arXiv_src_2003_048...
# Downloading arXiv_src_2003_050...
# Downloading arXiv_src_2003_049...
# Downloading arXiv_src_2003_046...
# Downloading arXiv_src_2003_047...
# Downloading arXiv_src_2003_045...
# Downloading arXiv_src_2003_032...
# Downloading arXiv_src_2003_044...
# Downloading arXiv_src_2003_043...
# Downloading arXiv_src_2003_042...
# Downloading arXiv_src_2003_041...
# Downloading arXiv_src_2003_039...
# Downloading arXiv_src_2003_040...
# Downloading arXiv_src_2003_038...
# Downloading arXiv_src_2003_037...
# Downloading arXiv_src_2003_036...
# Downloading arXiv_src_2003_035...
# Downloading arXiv_src_2003_033...
# Downloading arXiv_src_2003_034...
# Downloading arXiv_src_2003_030...
# Downloading arXiv_src_2003_031...
# Downloading arXiv_src_2003_029...
# Downloading arXiv_src_2003_028...
# Downloading arXiv_src_2003_027...
# Downloading arXiv_src_2003_026...
# Downloading arXiv_src_2003_025...
# Downloading arXiv_src_2003_024...
# Downloading arXiv_src_2003_022...
# Downloading arXiv_src_2003_023...
# Downloading arXiv_src_2003_021...
# Downloading arXiv_src_2003_019...
# Downloading arXiv_src_2003_020...
# Downloading arXiv_src_2003_018...
# Downloading arXiv_src_2003_017...
# Downloading arXiv_src_2003_016...
# Downloading arXiv_src_2003_015...
# Downloading arXiv_src_2003_014...
# Downloading arXiv_src_2003_013...
# Downloading arXiv_src_2003_012...
# Downloading arXiv_src_2003_011...
# Downloading arXiv_src_2003_010...
# Downloading arXiv_src_2003_009...
# Downloading arXiv_src_2003_008...
# Downloading arXiv_src_2003_005...
# Downloading arXiv_src_2003_006...
# Downloading arXiv_src_2003_007...
# Downloading arXiv_src_2003_004...
# Downloading arXiv_src_2003_003...
# Downloading arXiv_src_2003_002...
# Downloading arXiv_src_2003_001...
# Downloading arXiv_src_2002_042...
# Downloading arXiv_src_2002_041...
# Downloading arXiv_src_2002_040...
# Downloading arXiv_src_2002_039...
# Downloading arXiv_src_2002_038...
# Downloading arXiv_src_2002_037...
# Downloading arXiv_src_2002_034...
# Downloading arXiv_src_2002_035...
# Downloading arXiv_src_2002_036...
# Downloading arXiv_src_2002_033...
# Downloading arXiv_src_2002_032...
# Downloading arXiv_src_2002_031...
# Downloading arXiv_src_2002_030...
# Downloading arXiv_src_2002_029...
# Downloading arXiv_src_2002_027...
# Downloading arXiv_src_2002_028...
# Downloading arXiv_src_2002_026...
# Downloading arXiv_src_2002_024...
# Downloading arXiv_src_2002_025...
# Downloading arXiv_src_2002_023...
# Downloading arXiv_src_2002_022...
# Downloading arXiv_src_2002_021...
# Downloading arXiv_src_2002_020...
# Downloading arXiv_src_2002_019...
# Downloading arXiv_src_2002_018...
# Downloading arXiv_src_2002_017...
# Downloading arXiv_src_2002_016...
# Downloading arXiv_src_2002_015...
# Downloading arXiv_src_2002_014...
# Downloading arXiv_src_2002_013...
# Downloading arXiv_src_2002_012...
# Downloading arXiv_src_2002_011...
# Downloading arXiv_src_2002_009...
# Downloading arXiv_src_2002_008...
# Downloading arXiv_src_2002_010...
# Downloading arXiv_src_2002_007...
# Downloading arXiv_src_2002_006...
# Downloading arXiv_src_2002_005...
# Downloading arXiv_src_2002_003...
# Downloading arXiv_src_2002_004...
# Downloading arXiv_src_2002_002...
# Downloading arXiv_src_2002_001...
# Downloading arXiv_src_2001_039...
# Downloading arXiv_src_2001_040...
# Downloading arXiv_src_2001_036...
# Downloading arXiv_src_2001_037...
# Downloading arXiv_src_2001_038...
# Downloading arXiv_src_2001_034...
# Downloading arXiv_src_2001_035...
# Downloading arXiv_src_2001_033...
# Downloading arXiv_src_2001_032...
# Downloading arXiv_src_2001_031...
# Downloading arXiv_src_2001_030...
# Downloading arXiv_src_2001_029...
# Downloading arXiv_src_2001_027...
# Downloading arXiv_src_2001_028...
# Downloading arXiv_src_2001_026...
# Downloading arXiv_src_2001_025...
# Downloading arXiv_src_2001_024...
# Downloading arXiv_src_2001_023...
# Downloading arXiv_src_2001_022...
# Downloading arXiv_src_2001_021...
# Downloading arXiv_src_2001_020...
# Downloading arXiv_src_2001_018...
# Downloading arXiv_src_2001_019...
# Downloading arXiv_src_2001_017...
# Downloading arXiv_src_2001_016...
# Downloading arXiv_src_2001_014...
# Downloading arXiv_src_2001_015...
# Downloading arXiv_src_2001_013...
# Downloading arXiv_src_2001_012...
# Downloading arXiv_src_2001_011...
# Downloading arXiv_src_2001_008...
# Downloading arXiv_src_2001_010...
# Downloading arXiv_src_2001_009...
# Downloading arXiv_src_2001_007...
# Downloading arXiv_src_2001_005...
# Downloading arXiv_src_2001_006...
# Downloading arXiv_src_2001_004...
# Downloading arXiv_src_2001_003...
# Downloading arXiv_src_2001_001...
# Downloading arXiv_src_2001_002...
# Downloading arXiv_src_1912_043...
# Downloading arXiv_src_1912_044...
# Downloading arXiv_src_1912_042...
# Downloading arXiv_src_1912_040...
# Downloading arXiv_src_1912_041...
# Downloading arXiv_src_1912_039...
# Downloading arXiv_src_1912_038...
# Downloading arXiv_src_1912_037...
# Downloading arXiv_src_1912_036...
# Downloading arXiv_src_1912_034...
# Downloading arXiv_src_1912_033...
# Downloading arXiv_src_1912_032...
# Downloading arXiv_src_1912_031...
# Downloading arXiv_src_1912_030...
# Downloading arXiv_src_1912_028...
# Downloading arXiv_src_1912_029...
# Downloading arXiv_src_1912_027...
# Downloading arXiv_src_1912_026...
# Downloading arXiv_src_1912_025...
# Downloading arXiv_src_1912_024...
# Downloading arXiv_src_1912_023...
# Downloading arXiv_src_1912_022...
# Downloading arXiv_src_1912_021...
# Downloading arXiv_src_1912_019...
# Downloading arXiv_src_1912_018...
# Downloading arXiv_src_1912_017...
# Downloading arXiv_src_1912_016...
# Downloading arXiv_src_1912_014...
# Downloading arXiv_src_1912_015...
# Downloading arXiv_src_1912_013...
# Downloading arXiv_src_1912_012...
# Downloading arXiv_src_1912_011...
# Downloading arXiv_src_1912_010...
# Downloading arXiv_src_1912_007...
# Downloading arXiv_src_1912_008...
# Downloading arXiv_src_1912_009...
# Downloading arXiv_src_1912_006...
# Downloading arXiv_src_1912_004...
# Downloading arXiv_src_1912_005...
# Downloading arXiv_src_1912_003...
# Downloading arXiv_src_1912_001...
# Downloading arXiv_src_1912_002...
